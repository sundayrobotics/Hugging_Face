# %%
import sounddevice as sd
from scipy.io.wavfile import write
import librosa

# %%
fs =16000 #sample rate
seconds = 3 #recording duration

myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
sd.wait() #wait until recording is done
write('output.wav', fs, myrecording) #save as wav file

# %%
import IPython.display as display
display.Audio("output.wav", autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio, rate = librosa.load("output.wav")
rate
# Out:
# 22050

# %%
audio, rate = librosa.load("output.wav", sr=16000)

# %%
audio
# Out:
# array([ 0.64169323,  1.0867667 ,  0.96616524, ..., -0.12751052,
#        -0.13033347, -0.15022594], dtype=float32)

# %%
rate
# Out:
# 16000
